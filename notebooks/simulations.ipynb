# %% [markdown]
# ## Tony Nunn <br>
# ## ME555 Robot Learning <br>
# ## Simulations

# %%
#imports
import sys
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import scipy.io
import os

# %% [markdown]
# #### Run Simulation

# %% [markdown]
# import subprocess
# import sys
#
# sim_file = r"C:\Projects\EMG_Motion\src\simulation\run_simulation.py"
#
# subprocess.Popen([sys.executable, sim_file])
